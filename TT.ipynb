# %%
import TTest as main
import numpy as np
import Picture.calculateW as calc

data = main.ReadData(10000)
def GetRealY(index):
    list = []
    for i in data[1]:
        list.append(i[index])
    list = np.array(list)
    return list


x = np.array(data[0])
z = calc.GetYProd(np.array(data[0]), np.array([1] * len(data[0][0])), 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900

# %%
from keras.datasets import mnist
import Picture.convertToData as convert
import Picture.pictureToPixel as toPix
import matplotlib.pyplot as plt
import Picture.calculateW as calc
import numpy as np
from keras.utils import to_categorical
(trainImage, trainLabel), (testImage, testLabel) = mnist.load_data()
def GradientNew(x, y, w, b):
  yCalc = calc.GetYProd(x, w, b)
  bG = (yCalc - y).mean()
  wG = np.zeros(x.shape[1])
  for i in range(x.shape[1]):
    wG[i] = (x[:, i] * (yCalc - y)).mean()
  return wG, bG

def GradientRunNew(x, maxNum, learningRateNum, col):
  learningRate = 1
  y = GetRealY(col)
  initW = np.array([0.0] * len(data[0][0]))
  initB = 0
  costBack = -1
  for i in range(maxNum):
    stepW, stepB = GradientNew(x, y, np.array([1] * len(data[0][0])), initB)
    initW -= learningRate * stepW
    initB -= learningRate * stepB
    yCalc = calc.GetYProd(x, initW, initB)
    cost = calc.CalcDistance(y, yCalc)
    if(i % 100 == 0):
      print(f"Running, {i/maxNum * 100:.2f}%, cost: {cost}")
    if(costBack < 0 or costBack > cost):
      costBack = cost
    elif(costBack <= cost):
      print("reverse")
      print(f"Running, {i/maxNum * 100:.2f}%, cost: {cost}")
      learningRate /= 10
      learningRateNum -= 1
      if(learningRateNum == 0):
        print(cost)
        print("over")
        return initW , initB 

  return initW, initB
def GetCurrentImage(num, index):
    # (trainImage, trainLabel), (testImage, testLabel) = mnist.load_data()
    trainLabels = to_categorical(trainLabel)
    pixel = trainImage[num]
    pixel = convert.PixelNormalize(pixel)
    pixel = convert.ToPooling([pixel, pixel, pixel], 26)
    line = np.array(convert.ToLine(pixel[0]))
    return pixel, line, trainLabels[num][index]

def CheckAcc(line, ans, w, b):
    x = (line * w).sum() + b
    return x

# %%
w = []
b = []
for i in range(10):
    print(f"run {i}")
    w1, b1 = GradientRunNew(x, 10000, 10, i)
    w.append(np.array(w1))
    b.append(np.array(b1))

# %%
w = np.array(w)
wNew = w.mean(axis=0)
b = np.array(b)
bNew = b.mean()
(trainImage, trainLabel), (testImage, testLabel) = mnist.load_data()
trainLabel
numTotal = 0
numCorrect = 0
for i in range(2000, 2100):
    list = []
    for j in range(10):
        pixel, line, ans = GetCurrentImage(i, j)
        per = (int)(CheckAcc(line, ans, w[j], b[j])*100)/100
        list.append(per)
    sorted_indices = np.argsort(list)
    if(trainLabel[i] == sorted_indices[-1]):
        numCorrect += 1
    numTotal += 1
    print(f"Num of: {numTotal}, Answer is {trainLabel[i]} result is {sorted_indices[-1]}, accuracy: {numCorrect / numTotal * 100:.2f}%")

print(f"Final accuracy is {numCorrect / numTotal * 100:.2f}%")
# Out:
# Num of: 1, Answer is 5 result is 0, accuracy: 0.00%
# Num of: 2, Answer is 8 result is 8, accuracy: 50.00%
# Num of: 3, Answer is 8 result is 8, accuracy: 66.67%
# Num of: 4, Answer is 4 result is 9, accuracy: 50.00%
# Num of: 5, Answer is 2 result is 2, accuracy: 60.00%
# Num of: 6, Answer is 6 result is 6, accuracy: 66.67%
# Num of: 7, Answer is 9 result is 9, accuracy: 71.43%
# Num of: 8, Answer is 7 result is 7, accuracy: 75.00%
# Num of: 9, Answer is 1 result is 8, accuracy: 66.67%
# Num of: 10, Answer is 0 result is 0, accuracy: 70.00%
# Num of: 11, Answer is 2 result is 0, accuracy: 63.64%
# Num of: 12, Answer is 3 result is 3, accuracy: 66.67%
# Num of: 13, Answer is 1 result is 3, accuracy: 61.54%
# Num of: 14, Answer is 8 result is 8, accuracy: 64.29%
# Num of: 15, Answer is 7 result is 0, accuracy: 60.00%
# Num of: 16, Answer is 1 result is 8, accuracy: 56.25%
# Num of: 17, Answer is 8 result is 8, accuracy: 58.82%
# Num of: 18, Answer is 2 result is 2, accuracy: 61.11%
# Num of: 19, Answer is 7 result is 2, accuracy: 57.89%
# Num of: 20, Answer is 2 result is 6, accuracy: 55.00%
# Num of: 21, Answer is 6 result is 6, accuracy: 57.14%
# Num of: 22, Answer is 3 result is 3, accuracy: 59.09%
# Num of: 23, Answer is 2 result is 2, accuracy: 60.87%
# Num of: 24, Answer is 3 result is 3, accuracy: 62.50%
# Num of: 25, Answer is 7 result is 7, accuracy: 64.00%
# Num of: 26, Answer is 6 result is 6, accuracy: 65.38%
# Num of: 27, Answer is 8 result is 0, accuracy: 62.96%
# Num of: 28, Answer is 7 result is 7, accuracy: 64.29%
# Num of: 29, Answer is 5 result is 8, accuracy: 62.07%
# Num of: 30, Answer is 3 result is 3, accuracy: 63.33%
# Num of: 31, Answer is 8 result is 3, accuracy: 61.29%
# Num of: 32, Answer is 4 result is 4, accuracy: 62.50%
# Num of: 33, Answer is 4 result is 4, accuracy: 63.64%
# Num of: 34, Answer is 9 result is 9, accuracy: 64.71%
# Num of: 35, Answer is 4 result is 0, accuracy: 62.86%
# Num of: 36, Answer is 6 result is 6, accuracy: 63.89%
# Num of: 37, Answer is 4 result is 0, accuracy: 62.16%
# Num of: 38, Answer is 5 result is 0, accuracy: 60.53%
# Num of: 39, Answer is 5 result is 0, accuracy: 58.97%
# Num of: 40, Answer is 1 result is 8, accuracy: 57.50%
# Num of: 41, Answer is 1 result is 3, accuracy: 56.10%
# Num of: 42, Answer is 9 result is 9, accuracy: 57.14%
# Num of: 43, Answer is 3 result is 3, accuracy: 58.14%
# Num of: 44, Answer is 8 result is 8, accuracy: 59.09%
# Num of: 45, Answer is 6 result is 8, accuracy: 57.78%
# Num of: 46, Answer is 1 result is 8, accuracy: 56.52%
# Num of: 47, Answer is 4 result is 8, accuracy: 55.32%
# Num of: 48, Answer is 1 result is 1, accuracy: 56.25%
# Num of: 49, Answer is 7 result is 7, accuracy: 57.14%
# Num of: 50, Answer is 5 result is 0, accuracy: 56.00%
# Num of: 51, Answer is 4 result is 9, accuracy: 54.90%
# Num of: 52, Answer is 0 result is 0, accuracy: 55.77%
# Num of: 53, Answer is 4 result is 4, accuracy: 56.60%
# Num of: 54, Answer is 2 result is 2, accuracy: 57.41%
# Num of: 55, Answer is 7 result is 7, accuracy: 58.18%
# Num of: 56, Answer is 7 result is 7, accuracy: 58.93%
# Num of: 57, Answer is 5 result is 0, accuracy: 57.89%
# Num of: 58, Answer is 8 result is 3, accuracy: 56.90%
# Num of: 59, Answer is 0 result is 0, accuracy: 57.63%
# Num of: 60, Answer is 6 result is 6, accuracy: 58.33%
# Num of: 61, Answer is 9 result is 9, accuracy: 59.02%
# Num of: 62, Answer is 6 result is 6, accuracy: 59.68%
# Num of: 63, Answer is 6 result is 6, accuracy: 60.32%
# Num of: 64, Answer is 8 result is 8, accuracy: 60.94%
# Num of: 65, Answer is 7 result is 2, accuracy: 60.00%
# Num of: 66, Answer is 2 result is 2, accuracy: 60.61%
# Num of: 67, Answer is 0 result is 0, accuracy: 61.19%
# Num of: 68, Answer is 8 result is 8, accuracy: 61.76%
# Num of: 69, Answer is 8 result is 3, accuracy: 60.87%
# Num of: 70, Answer is 4 result is 4, accuracy: 61.43%
# Num of: 71, Answer is 8 result is 8, accuracy: 61.97%
# Num of: 72, Answer is 4 result is 0, accuracy: 61.11%
# Num of: 73, Answer is 4 result is 3, accuracy: 60.27%
# Num of: 74, Answer is 2 result is 2, accuracy: 60.81%
# Num of: 75, Answer is 3 result is 3, accuracy: 61.33%
# Num of: 76, Answer is 2 result is 2, accuracy: 61.84%
# Num of: 77, Answer is 3 result is 3, accuracy: 62.34%
# Num of: 78, Answer is 8 result is 0, accuracy: 61.54%
# Num of: 79, Answer is 2 result is 3, accuracy: 60.76%
# Num of: 80, Answer is 0 result is 0, accuracy: 61.25%
# Num of: 81, Answer is 5 result is 3, accuracy: 60.49%
# Num of: 82, Answer is 0 result is 0, accuracy: 60.98%
# Num of: 83, Answer is 0 result is 0, accuracy: 61.45%
# Num of: 84, Answer is 1 result is 1, accuracy: 61.90%
# Num of: 85, Answer is 0 result is 0, accuracy: 62.35%
# Num of: 86, Answer is 2 result is 2, accuracy: 62.79%
# Num of: 87, Answer is 1 result is 1, accuracy: 63.22%
# Num of: 88, Answer is 3 result is 3, accuracy: 63.64%
# Num of: 89, Answer is 3 result is 3, accuracy: 64.04%
# Num of: 90, Answer is 4 result is 8, accuracy: 63.33%
# Num of: 91, Answer is 7 result is 7, accuracy: 63.74%
# Num of: 92, Answer is 5 result is 3, accuracy: 63.04%
# Num of: 93, Answer is 3 result is 3, accuracy: 63.44%
# Num of: 94, Answer is 6 result is 6, accuracy: 63.83%
# Num of: 95, Answer is 1 result is 8, accuracy: 63.16%
# Num of: 96, Answer is 7 result is 7, accuracy: 63.54%
# Num of: 97, Answer is 6 result is 6, accuracy: 63.92%
# Num of: 98, Answer is 8 result is 8, accuracy: 64.29%
# Num of: 99, Answer is 3 result is 7, accuracy: 63.64%
# Num of: 100, Answer is 9 result is 9, accuracy: 64.00%
# Final accuracy is 64.00%
