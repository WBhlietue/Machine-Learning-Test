# %%
import TTest as main
import numpy as np
import Picture.calculateW as calc

data = main.ReadData(10000)
def GetRealY(index):
    list = []
    for i in data[1]:
        list.append(i[index])
    list = np.array(list)
    return list


x = np.array(data[0])
z = calc.GetYProd(np.array(data[0]), np.array([1] * len(data[0][0])), 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900

# %%
from keras.datasets import mnist
import Picture.convertToData as convert
import Picture.pictureToPixel as toPix
import matplotlib.pyplot as plt
import Picture.calculateW as calc
import numpy as np
from keras.utils import to_categorical
def GradientNew(x, y, w, b):
  yCalc = calc.GetYProd(x, w, b)
  bG = (yCalc - y).mean()
  wG = np.zeros(x.shape[1])
  for i in range(x.shape[1]):
    wG[i] = (x[:, i] * (yCalc - y)).mean()
  return wG, bG

def GradientRunNew(x, maxNum, learningRateNum, col):
  learningRate = 1
  y = GetRealY(col)
  initW = np.array([0.0] * len(data[0][0]))
  initB = 0
  costBack = -1
  for i in range(maxNum):
    stepW, stepB = GradientNew(x, y, np.array([1] * len(data[0][0])), initB)
    initW -= learningRate * stepW
    initB -= learningRate * stepB
    yCalc = calc.GetYProd(x, initW, initB)
    cost = calc.CalcDistance(y, yCalc)
    if(i % 100 == 0):
      print(f"Running, {i/maxNum * 100:.2f}%, cost: {cost}")
    if(costBack < 0 or costBack > cost):
      costBack = cost
    elif(costBack <= cost):
      print("reverse")
      print(f"Running, {i/maxNum * 100:.2f}%, cost: {cost}")
      learningRate /= 10
      learningRateNum -= 1
      if(learningRateNum == 0):
        print(cost)
        print("over")
        return initW , initB 

  return initW, initB
def GetCurrentImage(num, index):
    (trainImage, trainLabel), (testImage, testLabel) = mnist.load_data()
    trainLabel = to_categorical(trainLabel)
    pixel = trainImage[num]
    pixel = convert.PixelNormalize(pixel)
    pixel = convert.ToPooling([pixel, pixel, pixel], 26)
    line = np.array(convert.ToLine(pixel[0]))
    return pixel, line, trainLabel[num][index]

def CheckAcc(line, ans, w, b):
    x = (line * w).sum() + b
    return x

# %%
w = []
b = []
for i in range(10):
    print(f"run {i}")
    w1, b1 = GradientRunNew(x, 10000, 10, i)
    w.append(np.array(w1))
    b.append(np.array(b1))
# Out:
# run 0
# Running, 0.00%, cost: 0.1001
# c:\Haku\Other\M\Picture\calculateW.py:5: RuntimeWarning: overflow encountered in exp
#   return (1 / (1+ np.exp(-x)))
# reverse
# Running, 0.01%, cost: 0.1001
# reverse
# Running, 0.02%, cost: 0.1001
# reverse
# Running, 0.03%, cost: 0.1001
# reverse
# Running, 0.04%, cost: 0.1001
# reverse
# Running, 0.05%, cost: 0.1001
# reverse
# Running, 0.06%, cost: 0.1001
# reverse
# Running, 0.07%, cost: 0.1001
# reverse
# Running, 0.08%, cost: 0.1001
# reverse
# Running, 0.09%, cost: 0.1001
# reverse
# Running, 0.10%, cost: 0.1001
# 0.1001
# over
# run 1
# Running, 0.00%, cost: 0.1127
# reverse
# Running, 0.01%, cost: 0.1127
# reverse
# Running, 0.02%, cost: 0.1127
# reverse
# Running, 0.03%, cost: 0.1127
# reverse
# Running, 0.04%, cost: 0.1127
# reverse
# Running, 0.05%, cost: 0.1127
# reverse
# Running, 0.06%, cost: 0.1127
# reverse
# Running, 0.07%, cost: 0.1127
# reverse
# Running, 0.08%, cost: 0.1127
# reverse
# Running, 0.09%, cost: 0.1127
# reverse
# Running, 0.10%, cost: 0.1127
# 0.1127
# over
# run 2
# Running, 0.00%, cost: 0.0991
# reverse
# Running, 0.01%, cost: 0.0991
# reverse
# Running, 0.02%, cost: 0.0991
# reverse
# Running, 0.03%, cost: 0.0991
# reverse
# Running, 0.04%, cost: 0.0991
# reverse
# Running, 0.05%, cost: 0.0991
# reverse
# Running, 0.06%, cost: 0.0991
# reverse
# Running, 0.07%, cost: 0.0991
# reverse
# Running, 0.08%, cost: 0.0991
# reverse
# Running, 0.09%, cost: 0.0991
# reverse
# Running, 0.10%, cost: 0.0991
# 0.0991
# over
# run 3
# Running, 0.00%, cost: 0.1032
# reverse
# Running, 0.01%, cost: 0.1032
# reverse
# Running, 0.02%, cost: 0.1032
# reverse
# Running, 0.03%, cost: 0.1032
# reverse
# Running, 0.04%, cost: 0.1032
# reverse
# Running, 0.05%, cost: 0.1032
# reverse
# Running, 0.06%, cost: 0.1032
# reverse
# Running, 0.07%, cost: 0.1032
# reverse
# Running, 0.08%, cost: 0.1032
# reverse
# Running, 0.09%, cost: 0.1032
# reverse
# Running, 0.10%, cost: 0.1032
# 0.1032
# over
# run 4
# Running, 0.00%, cost: 0.098
# reverse
# Running, 0.01%, cost: 0.098
# reverse
# Running, 0.02%, cost: 0.098
# reverse
# Running, 0.03%, cost: 0.098
# reverse
# Running, 0.04%, cost: 0.098
# reverse
# Running, 0.05%, cost: 0.098
# reverse
# Running, 0.06%, cost: 0.098
# reverse
# Running, 0.07%, cost: 0.098
# reverse
# Running, 0.08%, cost: 0.098
# reverse
# Running, 0.09%, cost: 0.098
# reverse
# Running, 0.10%, cost: 0.098
# 0.098
# over
# run 5
# Running, 0.00%, cost: 0.0863
# reverse
# Running, 0.01%, cost: 0.0863
# reverse
# Running, 0.02%, cost: 0.0863
# reverse
# Running, 0.03%, cost: 0.0863
# reverse
# Running, 0.04%, cost: 0.0863
# reverse
# Running, 0.05%, cost: 0.0863
# reverse
# Running, 0.06%, cost: 0.0863
# reverse
# Running, 0.07%, cost: 0.0863
# reverse
# Running, 0.08%, cost: 0.0863
# reverse
# Running, 0.09%, cost: 0.0863
# reverse
# Running, 0.10%, cost: 0.0863
# 0.0863
# over
# run 6
# Running, 0.00%, cost: 0.1014
# reverse
# Running, 0.01%, cost: 0.1014
# reverse
# Running, 0.02%, cost: 0.1014
# reverse
# Running, 0.03%, cost: 0.1014
# reverse
# Running, 0.04%, cost: 0.1014
# reverse
# Running, 0.05%, cost: 0.1014
# reverse
# Running, 0.06%, cost: 0.1014
# reverse
# Running, 0.07%, cost: 0.1014
# reverse
# Running, 0.08%, cost: 0.1014
# reverse
# Running, 0.09%, cost: 0.1014
# reverse
# Running, 0.10%, cost: 0.1014
# 0.1014
# over
# run 7
# Running, 0.00%, cost: 0.107
# reverse
# Running, 0.01%, cost: 0.107
# reverse
# Running, 0.02%, cost: 0.107
# reverse
# Running, 0.03%, cost: 0.107
# reverse
# Running, 0.04%, cost: 0.107
# reverse
# Running, 0.05%, cost: 0.107
# reverse
# Running, 0.06%, cost: 0.107
# reverse
# Running, 0.07%, cost: 0.107
# reverse
# Running, 0.08%, cost: 0.107
# reverse
# Running, 0.09%, cost: 0.107
# reverse
# Running, 0.10%, cost: 0.107
# 0.107
# over
# run 8
# Running, 0.00%, cost: 0.0944
# reverse
# Running, 0.01%, cost: 0.0944
# reverse
# Running, 0.02%, cost: 0.0944
# reverse
# Running, 0.03%, cost: 0.0944
# reverse
# Running, 0.04%, cost: 0.0944
# reverse
# Running, 0.05%, cost: 0.0944
# reverse
# Running, 0.06%, cost: 0.0944
# reverse
# Running, 0.07%, cost: 0.0944
# reverse
# Running, 0.08%, cost: 0.0944
# reverse
# Running, 0.09%, cost: 0.0944
# reverse
# Running, 0.10%, cost: 0.0944
# 0.0944
# over
# run 9
# Running, 0.00%, cost: 0.0978
# reverse
# Running, 0.01%, cost: 0.0978
# reverse
# Running, 0.02%, cost: 0.0978
# reverse
# Running, 0.03%, cost: 0.0978
# reverse
# Running, 0.04%, cost: 0.0978
# reverse
# Running, 0.05%, cost: 0.0978
# reverse
# Running, 0.06%, cost: 0.0978
# reverse
# Running, 0.07%, cost: 0.0978
# reverse
# Running, 0.08%, cost: 0.0978
# reverse
# Running, 0.09%, cost: 0.0978
# reverse
# Running, 0.10%, cost: 0.0978
# 0.0978
# over

# %%
w = np.array(w)
wNew = w.mean(axis=0)
b = np.array(b)
bNew = b.mean()
(trainImage, trainLabel), (testImage, testLabel) = mnist.load_data()
trainLabel
numTotal = 0
numCorrect = 0
for i in range(2000, 2100):
    list = []
    for j in range(10):
        pixel, line, ans = GetCurrentImage(i, j)
        per = (int)(CheckAcc(line, ans, w[j], b[j])*100)/100
        list.append(per)
    sorted_indices = np.argsort(list)
    if(trainLabel[i] == sorted_indices[-1]):
        numCorrect += 1
    numTotal += 1
    print(f"Num of: {numTotal}, Answer is {trainLabel[i]} result is {sorted_indices[-1]}, accuracy: {numCorrect / numTotal * 100:.2f}%")

print(f"Final accuracy is {numCorrect / numTotal * 100:.2f}%")
# Out:
# Num of: 1, Answer is 5 result is 0, accuracy: 0.00%
